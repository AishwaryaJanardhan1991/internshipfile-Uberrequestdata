# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data= pd.read_csv("C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/Project files internship/SQLcleaned data for python_uber request data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 6745 non-null   int64
#  1   Request_id         6745 non-null   int64
#  2   Pickup_point       6745 non-null   object
#  3   Driver_id          4095 non-null   float64
#  4   Trip_status        6745 non-null   object
#  5   Request_timestamp  6745 non-null   object
#  6   Drop_timestamp     2831 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 369.0+ KB

# %%
data.shape
# Out:
# (6745, 7)

# %%
print(data.columns)
# Out:
# Index(['Id', 'Request_id', 'Pickup_point', 'Driver_id', 'Trip_status',
#        'Request_timestamp', 'Drop_timestamp'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 Id   Request_id    Driver_id
# count  6745.000000  6745.000000  4095.000000
# mean   3373.000000  3384.644922   149.501343
# std    1947.258115  1955.099667    86.051994
# min       1.000000     1.000000     1.000000
# 25%    1687.000000  1691.000000    75.000000
# 50%    3373.000000  3387.000000   149.000000
# 75%    5059.000000  5080.000000   224.000000
# max    6745.000000  6766.000000   300.000000

# %%
data.describe
# Out:
# <bound method NDFrame.describe of         Id  Request_id Pickup_point  Driver_id        Trip_status  \
# 0        1         619      Airport        1.0     Trip Completed
# 1        2         867      Airport        1.0     Trip Completed
# 2        3        1807         City        1.0     Trip Completed
# 3        4        2532      Airport        1.0     Trip Completed
# 4        5        3112         City        1.0     Trip Completed
# ...    ...         ...          ...        ...                ...
# 6740  6741        6745         City        NaN  No Cars Available
# 6741  6742        6752      Airport        NaN  No Cars Available
# 6742  6743        6751         City        NaN  No Cars Available
# 6743  6744        6754         City        NaN  No Cars Available
# 6744  6745        6753      Airport        NaN  No Cars Available
#
#         Request_timestamp       Drop_timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# ...

# %%
data.head()
# Out:
#    Id  Request_id Pickup_point  Driver_id     Trip_status  \
# 0   1         619      Airport        1.0  Trip Completed
# 1   2         867      Airport        1.0  Trip Completed
# 2   3        1807         City        1.0  Trip Completed
# 3   4        2532      Airport        1.0  Trip Completed
# 4   5        3112         City        1.0  Trip Completed
#
#      Request_timestamp       Drop_timestamp
# 0      11/7/2016 11:51      11/7/2016 13:00
# 1      11/7/2016 17:57      11/7/2016 18:47
# 2       12/7/2016 9:17       12/7/2016 9:58
# 3      12/7/2016 21:08      12/7/2016 22:03
# 4  13-07-2016 08:33:16  13-07-2016 09:25:47

# %%
# checking for null value
print("Missing values:\n", df.isna().sum())
# Out:
# Missing values:
#  Request_id              0
# Pickup_point            0
# Driver_id            2650
# Status                  0
# Request_timestamp    4071
# Drop_timestamp       5595
# dtype: int64

# %%
##converting to timestamp
data['Request_timestamp'] = pd.to_datetime(data['Request_timestamp'], errors='coerce')
data['Drop_timestamp'] = pd.to_datetime(data['Drop_timestamp'], errors = 'coerce')

# %%
#final checking
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 6745 non-null   int64
#  1   Request_id         6745 non-null   int64
#  2   Pickup_point       6745 non-null   object
#  3   Driver_id          4095 non-null   float64
#  4   Trip_status        6745 non-null   object
#  5   Request_timestamp  2674 non-null   datetime64[ns]
#  6   Drop_timestamp     1150 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(2)
# memory usage: 369.0+ KB
# None

# %%
# storing data in csv file
data.to_csv("data1.csv", index=False)

# %%
# changing the time to hour format
data['Request_hour'] = data['Request_timestamp'].dt.hour

# %%
# defining time parameters for different time range
def get_time_slot(hour):
    if pd.isnull(hour): return 'Unknown'
    elif 4 <= hour < 8: return 'Early Morning'
    elif 8 <= hour < 12: return 'Morning'
    elif 12 <= hour < 16: return 'Afternoon'
    elif 16 <= hour < 20: return 'Evening'
    elif 20 <= hour <= 23: return 'Night'
    else: return 'Late Night'

# %%
data['Time_slot'] = data['Request_hour'].apply(get_time_slot)

# %%
# Value counts
print("Status distribution:", data['Trip_status'].value_counts())
print("Pickup point distribution:", data['Pickup_point'].value_counts())
# Out:
# Status distribution: Trip_status
# Trip Completed       2831
# No Cars Available    2650
# Cancelled            1264
# Name: count, dtype: int64
# Pickup point distribution: Pickup_point
# City       3507
# Airport    3238
# Name: count, dtype: int64

# %%
# Requests by each hour(plot 1)
hourly_requests = data['Request_hour'].value_counts().sort_index()
hourly_requests.plot(kind='bar', title='Requests per Hour', xlabel='Hour', ylabel='Request Count')
plt.show()

# %%
# Requests by time slot and status(plot 2)
sns.countplot(data=data, x='Time_slot', hue='Trip_status')
plt.title('Request Status by Time Slot')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Status by Pickup Point(plot 3)
sns.countplot(data=data, x='Pickup_point', hue='Trip_status')
plt.title('Request Status by Pickup Point')
plt.show()

# %%
heatmap_data = data.pivot_table(
    index='Request_hour',
    columns='Pickup_point',
    values='Request_id',
    aggfunc='count')

# %%
# Ploting heatmap(plot 4)
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, cmap='Blues', fmt='g')
plt.title('Request Frequency by Hour and Pickup Point')
plt.xlabel('Pickup Point')
plt.ylabel('Request Hour')
plt.tight_layout()
plt.show()

# %%
# Pie chart of trip status(plot 5)
status_counts = df['Status'].value_counts()
plt.figure(figsize=(6, 4))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140, colors=['#66b1df','#fd9999','#98fd99'])
plt.title('Overall Trip Status Distribution')
plt.axis('equal')
plt.show()

# %%
#  Pickup point demand (plot 6)
plt.figure(figsize=(6,4))
sns.countplot(x='pickup_point', data=data_1)
plt.title('Pickup Point Demand')
plt.xlabel('Pickup Point')
plt.ylabel('Number of Requests')
plt.show()
